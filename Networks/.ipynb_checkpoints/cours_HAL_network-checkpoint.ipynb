# %%
import requests
import pandas as pd
import io
import collections
from itertools import combinations
import networkx as nx
pd.options.display.max_colwidth = 100
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Introduction
# HAL est la plateforme de dépôt qui centralise de nombreuses informations sur la recherche française: tous les chercheurs sont censé y déposer les références de leurs publications, et l'on peut également y trouver des informations sur les institutions, affiliation des chercheurs, etc.
#
# HAL propose un site web permettant de faire des recherches manuellement https://hal.archives-ouvertes.fr , mais aussi une API permettant de faire des requêtes à partir de code informatique.
#
# Cette API a une documentation assez sommaire, mais nous allons voir comment obtenir un ensemble d'informations de bases sur des publications, puis comment traiter ces informations à l'aide de python pour créer une visualization sous forme de graphes.
# La page principale de la documentation se trouve ici:
# https://api.archives-ouvertes.fr/docs/search
#
# Mais d'autres références utiles proposent des exemples de requêtes qui peuvent vous aider à obtenir ce que vous cherchez, notamment:
# * https://wiki.ccsd.cnrs.fr/wikis/hal/index.php/API:Recherche:Hal
# * https://api.archives-ouvertes.fr/docs/ref/?resource=structure&schema=fields
# * https://www.slideshare.net/OAccsd/usage-des-api-de-hal

# %% [markdown]
# # Requete: les bases
# En utilisant python, il suffit d'une ligne pour faire une requête à l'API. Une requête est une url (que l'on peut donc entrer aussi dans un navigateur comme n'importe quelle adresse web), qui décrit ce que l'on souhaite obtenir.
#
# Le début de l'url correspond à l'adresse de l'API de HAL et sera toujours la même: `http://api.archives-ouvertes.fr`.
# Pour faire des recherches sur des articles, on va ajouter `/search/` à la suite (ce serait différent pour chercher des informations sur les auteurs ou les structures, par exemple).
#
# Pour indiquer ce que l'on souhaite chercher, on va enfin rajouter le mot-clef `?q=MOT` où MOT est le mot qui nous intéresse. Par exemple, pour chercher mes publications, on pourra écrire:
# `http://api.archives-ouvertes.fr/search/?q=cazabet`
#
# Le nombre de réponses que l'on souhaite recevoir est indiqué avec l'option `rows=X`. Par défaut, X=30, et la valeur maximale est 10 000. Au delà, il faut utiliser un système un peu plus complexe, expliqué plus tard.

# %%
# On fait la requête et l'on met le resultat dans la variable "response"
response = requests.get("http://api.archives-ouvertes.fr/search/?q=cazabet&rows=3")

#On affiche le résultat. Par défaut, le résultat est en json. Pour chaque article, une citation standard est fournie.
response.json()
# Out:
# {'response': {'numFound': 27,
#   'start': 0,
#   'docs': [{'docid': 2016671,
#     'label_s': 'Rémi Vaudaine, Christine Largeron, Rémy Cazabet. Network properties captured by graph embeddings. Complex Network, 2018, Cambridge, United Kingdom. &#x27E8;hal-02016671&#x27E9;',
#     'uri_s': 'https://hal.archives-ouvertes.fr/hal-02016671'},
#    {'docid': 2456857,
#     'label_s': 'Rémi Vaudaine, Christine Largeron, Rémy Cazabet. Comparing the preservation of network properties by graph embeddings. Eighteenth International Symposium on Intelligent Data Analysis (IDA 2020), Apr 2020, Bodenseeforum, Germany. &#x27E8;hal-02456857&#x27E9;',
#     'uri_s': 'https://hal.archives-ouvertes.fr/hal-02456857'},
#    {'docid': 1500352,
#     'label_s': "Rémy Cazabet, Pierre Borgnat, Pablo Jensen. Using Degree Constrained Gravity Null-Models to understand the structure of journeys' networks in Bicycle Sharing Systems. ESANN 2017 - European Symposium on Artificial Neural Networks, Computational Intelligence and Machine Learning, Apr 2017, Bruges, Belgium. &#x27E8;hal-01500352&#x27E9;",
#     'uri_s': 'https://hal.archives-ouvertes.fr/hal-01500352'}]}}

# %% [markdown]
# # Requête: données détaillées
# Afin d'analyser les publications en détails, un résultat sous la forme d'un seul champ de texte n'est pas très pratique. Il est possible de préciser les données que l'on souhaite obtenir avec l'option:
# `fl=champ1,champ2,...,champX`.
# A ma connaissance, l'ensemble des champs possible n'est pas détaillé clairement dans l'API, et un très grand nombre de champs existent. Ci-dessous, j'ai dressé une liste des champs qui m'ont semblé les plus utiles:
# * `title_s`: Titre de l'article
# * `authFullName_s`: Nom complet des auteurs
# * `keyword_s`: Mots-clefs de l'article (lorsque disponible)
# * `publicationDate_s`: Date de publication
# * `publisher_s`: Éditeur
# * `docType_s`: Type de publication (conférence, article de journal, chapitre de livre, thèse...)
#
# * `structName_s`: Nom des structures auxquelles les auteurs appartiennent (attention, il y a fréquemment plusieurs structures par auteur)
# * `structCountry_s`: Pour chaque structure, le pays duquel il dépend
# * `structType_s`: Pour chaque strucutre, son type (laboratoire, université, regroupement d'université...)
# * `structAddress_s`: Pour chaque structure, son addresse
# * `structHasAuthId_fs`: Champ permettant de faire le lien entre les auteurs et les (multiples) structures.
#
# * `journalTitle_s`: Titre du journal (si c'est un journal, sinon vide)
# * `conferenceTitle_s`: Titre de la conférence (si c'est une conférence, sinon vide)

# %%
#Par exemple, si nous nous intéressons au titre des publications, aux affiliations des auteurs et 
#à l'année de publication:
response = requests.get("http://api.archives-ouvertes.fr/search/?q=cazabet&rows=2&fl=title_s,keyword_s,publicationDate_s,structName_s")
response.json()
# Out:
# {'response': {'numFound': 27,
#   'start': 0,
#   'docs': [{'title_s': ['Network properties captured by graph embeddings'],
#     'structName_s': ['Laboratoire Hubert Curien [Saint Etienne]',
#      "Institut d'Optique Graduate School",
#      'Université Jean Monnet [Saint-Étienne]',
#      'Centre National de la Recherche Scientifique',
#      'Université de Lyon'],
#     'publicationDate_s': '2018'},
#    {'title_s': ['Comparing the preservation of network properties by graph embeddings'],
#     'structName_s': ['Laboratoire Hubert Curien [Saint Etienne]',
#      'Université Jean Monnet [Saint-Étienne]',
#      'Centre National de la Recherche Scientifique',
#      "Institut d'Optique Graduate School"],
#     'publicationDate_s': '2020-04-27'}]}}

# %% [markdown]
# ## Résultats en csv et pandas
# Pour que le résultat soit plus lisible, on peut demander les résultats en .csv et les afficher avec pandas avec les
# commandes suivantes (notez l'ajout de l'option `wt=csv` pour spécifier le format. Voir https://api.archives-ouvertes.fr/docs/search pour les autres formats possible.)

# %%
response = requests.get("http://api.archives-ouvertes.fr/search/?q=cazabet&wt=csv&rows=6&fl=title_s,publicationDate_s,keyword_s,structName_s")
as_csv =pd.read_csv(io.StringIO(response.text),sep=",")
as_csv
# Out:
#                                                                                                title_s  \
# 0                                                      Network properties captured by graph embeddings
# 1                                 Comparing the preservation of network properties by graph embeddings
# 2  Using Degree Constrained Gravity Null-Models to understand the structure of journeys' networks i...
# 3                Enhancing Space-Aware Community Detection Using Degree Constrained Spatial Null Model
# 4  Tracking the Evolution of Temporal Patterns of Usage in Bicycle-Sharing Systems Using Nonnegativ...
# 5          Characterising Inter and Intra-Community Interactions in Link Streams Using Temporal Motifs
#
#   publicationDate_s  keyword_s  \
# 0              2018        NaN
# 1        2020-04-27        NaN
# 2           2017-04        NaN
# 3           2017-03        NaN
# 4              2017        NaN
# 5              2017        NaN
#
#                                                                                           structName_s
# 0  Laboratoire Hubert Curien [Saint Etienne],Institut d'Optique Graduate School,Université Jean Mon...
# 1  Laboratoire Hubert Curien [Saint Etienne],Université Jean Monnet [Saint-Étienne],Centre National...
# 2  ComplexNetworks,Laboratoire d'Informatique de Paris 6,Université Pierre et Marie Curie - Paris 6...
# 3  ComplexNetworks,Laboratoire d'Informatique de Paris 6,Université Pierre et Marie Curie - Paris 6...
# 4  ComplexNetworks,Laboratoire d'Informatique de Paris 6,Université Pierre et Marie Curie - Paris 6...
# 5  Equipe AMACC - Laboratoire GREYC - UMR6072,Groupe de Recherche en Informatique\, Image et Instru...

# %% [markdown]
# # Critères de recherche avancés
# Les critères de recherche peuvent être complexifiés : on peut imposer d'avoir plusieurs mots avec le mots-clef `AND`, avoir un mot ou un autre (`OR`), utiliser des jokers pour une lettre (`?`), pour un nombre quelconque de lettres (`*`), etc.
# La recherche peut être faite dans un champ particulier tel qu le titre ou les auteurs en précisant le champ sous la forme `Champ:requête`.
# La façon d'effectuer ces requêtes avancées est bien décrite avec des exemples dans la documentation: https://api.archives-ouvertes.fr/docs/search

# %%
#Par exemple, cherchons les articles écris par un auteur dont le nom est cazabet et qui contiennent 
#un mot commençant par commu (commu*) dans le titre, ce qui permettra de récupérer à la fois 
# community, communities, communautés, etc.
response = requests.get("http://api.archives-ouvertes.fr/search/?q=title_t:commu* AND authFullName_t:cazabet&wt=csv&fl=title_s,authFullName_s")
as_csv =pd.read_csv(io.StringIO(response.text),sep=",")
as_csv
# Out:
#                                                                                                 title_s  \
# 0   Détection de communautés dynamiques dans des réseaux temporels,Detection of dynamic communities ...
# 1           Characterising Inter and Intra-Community Interactions in Link Streams Using Temporal Motifs
# 2                                                Challenges in Community Discovery on Temporal Networks
# 3                                                     Community Discovery in Dynamic Networks: a Survey
# 4                 Enhancing Space-Aware Community Detection Using Degree Constrained Spatial Null Model
# 5                                                                           Dynamic Community Detection
# 6                           Evaluating Community Detection Algorithms for Progressively Evolving Graphs
# 7                Tracking bitcoin users activity using community detection on a network of weak signals
# 8           CDLIB: a python library to extract\, compare and evaluate communities from complex networks
# 9           OLCPM: An Online Framework for Detecting Overlapping Communities in Dynamic Social Networks
# 10                             Detecting Stable Communities in Link Streams at Multiple Temporal Scales
#
#                                              authFullName_s
# 0                                              Rémy Cazabet
# 1                              Jean Creusefond,Rémy Cazabet
# 2                              Rémy Cazabet,Giulio Rossetti
# 3                              Giulio Rossetti,Rémy Cazabet
# 4                  Rémy Cazabet,Pierre Borgnat,Pablo Jensen
# 5             Rémy Cazabet,Giulio Rossetti,Fredéric Amblard
# 6              Rémy Cazabet,Souâad Boudebza,Giulio Rossetti
# 7                  Rémy Cazabet,Rim Baccour,Matthieu Latapy
# 8                Giulio Rossetti,Letizia Milli,Rémy Cazabet
# 9   Souâad Boudebza,Rémy Cazabet,Faiçal Azouaou,Omar Nouali
# 10  Souâad Boudebza,Rémy Cazabet,Omar Nouali,Faiçal Azouaou

# %% [markdown]
# # Filtre par date
# Une autre option de filtre intéressante permet de chercher sur des intervalles de temps. On utilisera dans ce cas l'option `fq=champ_date:[debut TO fin]`, par exemple `fq=publicationDate_s:[2018 TO 2020]` pour se limiter aux articles publiés sur la période de 2018 à 2020. Se reporter à la documentation pour plus de détails.

# %%
response = requests.get("http://api.archives-ouvertes.fr/search/?q=authFullName_t:cazabet&fq=publicationDate_s:[2018 TO 2020]&wt=csv&fl=title_s,authFullName_s,publicationDateY_i")
as_csv =pd.read_csv(io.StringIO(response.text),sep=",")
as_csv
# Out:
#                                                                                        title_s  \
# 0                                       Challenges in Community Discovery on Temporal Networks
# 1                                            Community Discovery in Dynamic Networks: a Survey
# 2              Minimum entropy stochastic block models neglect edge distribution heterogeneity
# 3                                              Network properties captured by graph embeddings
# 4                                               Temporal Pattern Mining for E-commerce Dataset
# 5  Systematic Biases in Link Prediction: comparing heuristic and graph embedding based methods
# 6  CDLIB: a python library to extract\, compare and evaluate communities from complex networks
# 7  OLCPM: An Online Framework for Detecting Overlapping Communities in Dynamic Social Networks
# 8                     Detecting Stable Communities in Link Streams at Multiple Temporal Scales
#
#                                             authFullName_s  publicationDateY_i
# 0                             Rémy Cazabet,Giulio Rossetti                2019
# 1                             Giulio Rossetti,Rémy Cazabet                2018
# 2              Louis Duvivier,Céline Robardet,Rémy Cazabet                2019
# 3            Rémi Vaudaine,Christine Largeron,Rémy Cazabet                2018
# 4          Mohamad Kanaan,Rémy Cazabet,Hamamache Kheddouci                2020
# 5                  Aakash Sinha,Rémy Cazabet,Rémi Vaudaine                2018
# 6               Giulio Rossetti,Letizia Milli,Rémy Cazabet                2019
# 7  Souâad Boudebza,Rémy Cazabet,Faiçal Azouaou,Omar Nouali                2018
# 8  Souâad Boudebza,Rémy Cazabet,Omar Nouali,Faiçal Azouaou                2019

# %% [markdown]
# # Restriction à des sous-domaines de HAL
# L'un des intérêts de HAL est qu'il est organisé en sous-domaines: chaque université ou laboratoire, par exemple, peut se créer un sous-domaine, et seules les publications des chercheurs affilié à cette organisation en font partie. Il est possible de restreindre la requête à un sous-domaine particulier en ajoutant à l'URL de recherche, après `search`, le nom du sous-domaine. Par exemple:  `/search/UNIV-LYON/?q=XXX` pour chercher les publications de l'université de Lyon (regroupement d'universités de Lyon St-Etienne), ou `/search/LIRIS/?q=XXX` pour le laboratoire LIRIS (dont je fait partie depuis 2017)

# %%
# Notez que seules mes publications depuis 2017 apparaissent, puisqu'avant cela je ne faisait pas partie de cette
# institution
response = requests.get("http://api.archives-ouvertes.fr/search/LIRIS/?q=cazabet&wt=csv&fl=authFullName_s,structName_s,publicationDateY_i")
as_csv =pd.read_csv(io.StringIO(response.text),sep=",")
as_csv
# Out:
#                                                            authFullName_s  \
# 0                            Rémy Cazabet,Souâad Boudebza,Giulio Rossetti
# 1                   Alexandre Millot,Rémy Cazabet,Jean-François Boulicaut
# 2   Alexandre Millot,Romain Mathonat,Rémy Cazabet,Jean-François Boulicaut
# 3                   Alexandre Millot,Rémy Cazabet,Jean-François Boulicaut
# 4                   Alexandre Millot,Rémy Cazabet,Jean-François Boulicaut
# 5                             Louis Duvivier,Céline Robardet,Rémy Cazabet
# 6                             Louis Duvivier,Rémy Cazabet,Céline Robardet
# 7                 Souâad Boudebza,Rémy Cazabet,Faiçal Azouaou,Omar Nouali
# 8                         Mohamad Kanaan,Rémy Cazabet,Hamamache Kheddouci
# 9                                            Rémy Cazabet,Giulio Rossetti
# 10            Anes Bendimerad,Rémy Cazabet,Marc Plantevit,Céline Robardet
# 11                Souâad Boudebza,Rémy Cazabet,Omar Nouali,Faiçal Azouaou
# 12                                                           Rémy Cazabet
# 13                                           Giulio Rossetti,Rémy Cazabet
# 14                                Aakash Sinha,Rémy Cazabet,Rémi Vaudaine
# 15                               Rémy Cazabet,Rim Baccour,Matthieu Latapy
# 16                             Giulio Rossetti,Letizia Milli,Rémy Cazabet
#
#                                                                                            structName_s  \
# 0   Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 1   Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 2   Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 3   Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 4   Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 5   Laboratoire d'InfoRmatique en Image et Systèmes d'information,Institut National des Sciences App...
# 6   Institut National des Sciences Appliquées de Lyon,Université de Lyon,Institut National des Scien...
# 7   Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 8   Graphes\, AlgOrithmes et AppLications,Laboratoire d'InfoRmatique en Image et Systèmes d'informat...
# 9   Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 10  Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 11  École Nationale Supérieure d'Informatique [Alger],Data Mining and Machine Learning,Laboratoire d...
# 12  Data Mining and Machine Learning,Laboratoire d'InfoRmatique en Image et Systèmes d'information,I...
# 13  Pisa Research Area - National Research Council [Pise] (Italian National Research Council ),Unive...
# 14  Indian Institute of Technology Delhi,Data Mining and Machine Learning,Laboratoire d'InfoRmatique...
# 15  Université de Lyon,ComplexNetworks,Laboratoire d'Informatique de Paris 6,Université Pierre et Ma...
# 16  Istituto di Scienza e Tecnologie dell'Informazione “A. Faedo",Consiglio Nazionale delle Ricerche...
#
#     publicationDateY_i
# 0                 2020
# 1                 2020
# 2                 2020
# 3                 2020
# 4                 2021
# 5                 2019
# 6                 2021
# 7                 2018
# 8                 2020
# 9                 2019
# 10                2017
# 11                2019
# 12                2021
# 13                2018
# 14                2018
# 15                2017
# 16                2019

# %% [markdown]
# # Statistiques simples
# Bien que ce ne soit pas l'objet de ce cour, on peut noter qu'il est maintenant très facile de faire des statistiques simples sur ces données. Par exemple, le nombre de publication d'un auteur (ou d'une institution) par an, ou la proportion de publications d'un type donné

# %%
#NB: ici, les données sont incomplètes pour les premières années. 
#L'incitation aux chercheurs de mettre leurs publications dans HAL date environ de 2017, et est devenue obligatoire
# dans certains cas (financements ANR, Europe...) depuis 2019
response = requests.get("http://api.archives-ouvertes.fr/search/?q=cazabet&wt=csv&fl=docType_s,publicationDateY_i")
as_csv =pd.read_csv(io.StringIO(response.text),sep=",")

#en utilisant la librairie seaborn pour faire un histogramme
sns.histplot(as_csv["publicationDateY_i"],binwidth=1)
# Out:
# <AxesSubplot:xlabel='publicationDateY_i', ylabel='Count'>

# %%
# En utilisant l'outil graphique de pandas. COMM correspond à des communications dans des conférences, 
#ART à des articles dans des journeaux, COUV: chapitre d'ouvrage, DOUV: direction d'ouvrage
grouped=as_csv.groupby("docType_s")["docType_s"].count()
print(grouped)
grouped.plot.pie(autopct="%.0f%%")
# Out:
# docType_s
# ART       6
# COMM     15
# COUV      4
# DOUV      1
# THESE     1
# Name: docType_s, dtype: int64
# <AxesSubplot:ylabel='docType_s'>

# %% [markdown]
# # Grande quantité de données
# **(Une fonction réutilisable d'une ligne est fournie à la fin, le code est fourni pour référence)**
#
# Comme mentionné précédemment, la quantité d'éléments qui peuvent être retournés par une requête est limité à 10 000. Il est tout à fait possible de faire des requêtes plus importantes, mais il faut dans ce cas utiliser un système de pagination: le résultat est retourné en plusieurs pages qui peuvent être parcourues les unes après les autres.
#
# La méthode la plus simple consiste à demander des résultats triés par identifiants (`&sort=docid asc`), puis de demander de commencer à une certaine ligne avec l'option `&start=num_ligne"`.
#
# Ainsi, s'il y a 35000 résultats, on peut les obtenirs en demandant les 10 000 premiers, puis ceux de 10000 à 20000, de 20000 à 30000, et enfin de 30000 à 40000.
#
# Il est recommandé d'utiliser plutôt des pages de taille 1000 pour des raisons de performance.

# %%
#Imaginons que l'on souhaite récupérer tous les articles contenant les mots network et graphes.


#On définition la requête de base, sans options
requete="http://api.archives-ouvertes.fr/search/?q=(network AND graph)"



#On écrit une fonction (donc réutilisable) pour récupérer tous les éléments, page par page
def get_all_elements(request_core,page_size=1000):
    df_complet=pd.DataFrame()
    
    #en faisant la requête en json, on peut obtenir le nombre de réponses à récupérer
    nb_reponses=requests.get(request_core).json()["response"]["numFound"]
    print("Nombre d'éléments au total : ",nb_reponses)

    #Cette boucle incrémente le curseur de début, par pas de 1000, jusqu'à atteindre le dernier élément
    for i in range(0,nb_reponses,page_size):
        #On récupére le résultat, en rajoutant des options à la requete de base
        response =requests.get(requete+"&wt=csv&sort=docid asc&start="+str(i)+"&rows="+str(page_size))
        df_temp =pd.read_csv(io.StringIO(response.text),sep=",")

        #On ajoute les réponses les plus récentes à celles que l'on a déjà
        df_complet=df_complet.append(df_temp,ignore_index=True)
        print("Éléments récupérés : ",len(df_complet))
    
    return df_complet #la fonction renvoie le tableau complet

# %% [markdown]
# ## Nous pouvons maintenant faire une requête large en une seule ligne

# %%
requete="http://api.archives-ouvertes.fr/search/?q=(network AND graph)"

#On appelle la fonction sur notre requete
resultat = get_all_elements(requete)

#Nous pouvons vérifier qu'à la fin, nous avons bien le nombre d'éléments attendus dans notre tableau
resultat
# Out:
# Nombre d'éléments au total :  3319
# Éléments récupérés :  1000
# Éléments récupérés :  2000
# Éléments récupérés :  3000
# Éléments récupérés :  3319
#         docid         halId_s  version_i  docType_s  \
# 0        1347    hal-00001347          1        ART
# 1        2834    hal-00002263          1        ART
# 2       27744    hal-00003362          1        ART
# 3       28036    hal-00003550          1       COMM
# 4       32420  inria-00000158          1       COMM
# ...       ...             ...        ...        ...
# 3314  3379551    hal-03379551          1        ART
# 3315  3379857    hal-03379857          1        ART
# 3316  3381416    hal-03381370          1  UNDEFINED
# 3317  3383276    hal-03383140          2       COMM
# 3318  3384624    tel-03384624          1      THESE
#
#                                                                                            citationFull_s  \
# 0     Christophe Soule. Graphic requirements for multistationarity. <i>Complexus</i>, Karger, 2003, 1,...
# 1     Christophe Texier, Pascal Degiovanni. Charge and current distribution in graphs. <i>Journal of P...
# 2     Christian Lavault. Embeddings into the Pancake Interconnection Network. <i>Parallel Processing L...
# 3     Jacqueline Vauzeilles, Christophe Fouqueré. Inheritance with exceptions: an attempt at formaliza...
# 4     Samuel Landau, Olivier Sigaud, Marc Schoenauer. ATNoSFERES revisited. <i>GECCO 2005 - 7th annual...
# ...                                                                                                   ...
# 3314  Natalia Díaz-Rodríguez, Alberto Lamas, Jules Sanchez, Gianni Franchi, Ivan Donadello, et al.. EX...
# 3315  Sébastien Plutniak. Assyrian merchants meet nuclear physicists: history of the early contributio...
# 3316  Dounia Lakhzoum, Marie Izaute, Ludovic Ferrand. Semantic network analysis of abstract and concre...
# 3317  Rui Dai, Srijan Das, Francois Bremond. CTRN: CLASS TEMPORAL RELATIONAL NETWORK FOR ACTION DETECT...
# 3318  Nejat Arinik. Multiplicity in the Partitioning of Signed Graphs. Other [cs.OH]. Université d'Avi...
#
#                                                                                             citationRef_s
# 0                                                           <i>Complexus</i>, Karger, 2003, 1, pp.123-133
# 1     <i>Journal of Physics A: Mathematical and Theoretical</i>, IOP Publishing, 2003, 36, pp.12425-12452
# 2             <i>Parallel Processing Letters</i>, World Scientific Publishing, 2002, 12 (3-4), pp.297-310
# 3                                               <i>Advances in Linear Logic</i>, 1995, France. pp.167-196
# 4     <i>GECCO 2005 - 7th annual conference on Genetic and Evolutionary Computation Conference, </i>, ...
# ...                                                                                                   ...
# 3314  <i>Information Fusion</i>, Elsevier, 2021, <a target="_blank" href="https://dx.doi.org/10.1016/j...
# 3315  <i>Interdisciplinary Science Reviews</i>, Maney Publishing, 2021, 46 (4), pp.547-568. <a target=...
# 3316                                                                                                 2021
# 3317               <i>The British Machine Vision Conference (BMVC)</i>, Nov 2021, Virtual, United Kingdom
# 3318  Other [cs.OH]. Université d'Avignon, 2021. English. <a target="_blank" href="https://www.theses....
#
# [3319 rows x 6 columns]

# %% [markdown]
# # Création d'un réseau de co-auteurs
# **(Une fonction réutilisable d'une ligne est fournie à la fin, le code est fourni pour référence)**
#
# Imaginons que nous voulons étudier le réseau de co-auteurs (qui travaille avec qui) des chercheurs Lyonnais qui travaillent sur le thème des *networks*, en se limitant aux 10 dernières années. Nous allons procéder en 4 étapes:
# 1. Récupération des informations qui nous intéressent (articles d'intérêt et leurs auteurs)
# 2. Pour chaque article avec au moins 2 auteurs, compter un lien entre eux
# 3. À partir des liens, créer un réseau en utilisant la librairie networkx
# 4. Exporter le réseau dans un format standard accepté par le logiciel Gephi

# %%
requete = "http://api.archives-ouvertes.fr/search/UNIV-LYON/?q=abstract_t:(network -neural)&fq=publicationDate_s:[2012 TO 2022]&fl=title_s,authFullName_s,abstr*"
#co_aut = get_all_elements(requete)

# %%
def co_occurence_network(request,column,threshold=1):
    collab_list=[]
    node_list=[] #To make the network more insteresting, we also collect the number of articles by author:




    for collab in list(request[column]): #pour tous les articles
        nodes=collab.replace("\\,","_").split(",") #on crée une liste des noms d'auteurs
        if len(nodes)<=5: #s'il y a entre 2 et 5 elements (pour éviter une explostion de liens)
            
            for node in nodes:#remember we have seen that node
                node_list.append(node)
                
            for node1,node2 in combinations(nodes,2): #pour chaque paire d'auteurs possible dans la liste
                collab_list.append(frozenset((node1,node2))) #on ajoute une collaboration. 
                #noter l'usage du set (frozenset), qui dit qu'il n'y a pas d'ordre entre les éléments: 
                #set((lab1,lab2))==set((lab2,lab1)) alors que [aut1,aut2]!=[aut2,aut1]
    
    #We count how many times each node appears:
    nodes=[]
    occurences=node_list
    for n,occ in dict(collections.Counter(occurences)).items(): #collections.Counter count occurences by item
        if occ>threshold: #we filter out singleton to keep important actors
            nodes.append((n,{"occurences":occ})) #we store the result in a format convenient for networkx
    
    #We count how many times each link appears:
    edges=[]
    occurences=collab_list
    for n,occ in dict(collections.Counter(occurences)).items(): #collections.Counter count occurences by item
        if occ>threshold: #we filter out singleton to keep important relations
            n1,n2=n
            edges.append((n1,n2,{"occurences":occ})) #we store the result in a format convenient for networkx
            
    #En utilisant networkx, nous créons un objet graphe
    g = nx.Graph()
    g.add_nodes_from(nodes)
    g.add_edges_from(edges)
    return g

# %% [markdown]
# ## Nous pouvons maintenant utiliser cette fonction pour obtenir un réseau de co-autheur à partir d'une requête
# Il faut simplement que la requête contienne la colonne `authFullName_s`

# %%
requete = "http://api.archives-ouvertes.fr/search/UNIV-LYON/?q=abstract_t:(network -neural)&fq=publicationDate_s:[2012 TO 2022]&fl=title_s,authFullName_s,abstr*"
co_aut = get_all_elements(requete)
# Out:
# Nombre d'éléments au total :  2224
# Éléments récupérés :  1000
# Éléments récupérés :  2000
# Éléments récupérés :  2224

# %%
g = co_occurence_network(co_aut,"authFullName_s")

# %% [markdown]
# ### Visualisation et export
# La dernière étape consite à créer le graphe et à l'exporter.
# Après avoir créé l'objet graphe, nous pouvons simplement le visualiser pour vérifier que les données sont bien présentes. Cependant, il est recommandé d'exporter le graphe pour le visualiser avec *Gephi*

# %%
#Nous enlevons les noeud sans liens pour simplifier
g.remove_nodes_from(list(nx.isolates(g)))

# %%
#Nous le visualisons
plt.figure(1,figsize=(15,10)) 
pos=nx.fruchterman_reingold_layout(g)
nx.draw_networkx(g,pos=pos)

# %%
#Finalement, nous l'exportons au format graphml, qui permet de l'importer immédiatement dans Gephi.
#On peut noter que les attributs (nombre d'occurrences) des nœuds et liens seront accessibles
nx.write_graphml(g,"cocitation.graphml")

# %% [markdown]
# # Réseau de relations entre laboratoires
# Il est tout à fait possible d'utiliser d'autres informations pour créer d'autres types de réseaux.
# Par exemple, en réutilisant exactement la même méthode, nous pouvons créer un réseau de collaborations entre laboratoires.
#
# Les seules différences sont que:
# * Lors de la requête, nous ne nous limitons pas à Lyon, mais à l'ensemble de la France
# * Les nœuds correspondent à des laboratoires et non plus à des personnes
# * Un lien entre 2 laboratoires représente une collaboration entre 2 personnes de ce laboratoire.

# %%
requete="http://api.archives-ouvertes.fr/search/?q=abstract_t:(network -neural) AND structCountry_s:fr&fq=publicationDate_s:[2012 TO 2022]&fl=structAcronym_s,structCountry_s,structAddress_s,structType_s,structName_s"

# %%
def co_occurence_network_laboratory(request,column,threshold=1):
    collab_list=[]
    node_list=[]
    
    struct_names=list(request[column])
    struct_types=list(request["structType_s"]) # We also get types of structures
    struct_countries=list(request["structCountry_s"]) #and countries
    
    for i,collab in enumerate(struct_names):
        nodes_unfiltered=collab.replace("\\,","_").split(",") 
        
        #We split them the same way
        types=struct_types[i].replace("\\,","_").split(",") 
        countries=struct_countries[i].replace("\\,","_").split(",") 
        
        #We filter the structure (nodes) to keep only french laboratories
        nodes=set()
        try:
            for j,name in enumerate(nodes_unfiltered):
                if types[j]=="laboratory" and countries[j]=="fr":
                    nodes.add(name)
        except:#if there is a problem
            pass # ignore this item
        
        if len(nodes)>1:
            for node in nodes:
                node_list.append(node)

            if len(nodes)<=10: 
                for node1,node2 in combinations(nodes,2): 
                    collab_list.append(frozenset((node1,node2))) 

    nodes=[]
    occurences=node_list
    for n,occ in dict(collections.Counter(occurences)).items(): 
        if occ>threshold: 
            nodes.append((n,{"occurences":occ})) 
    
    edges=[]
    occurences=collab_list
    for n,occ in dict(collections.Counter(occurences)).items(): 
        if occ>threshold:
            n1,n2=n
            edges.append((n1,n2,{"occurences":occ}))
            
    g = nx.Graph()
    g.add_nodes_from(nodes)
    g.add_edges_from(edges)
    return g

# %%
colab_lab = get_all_elements(requete,5000)
# Out:
# Nombre d'éléments au total :  14
# Éléments récupérés :  14

# %%
g = co_occurence_network_laboratory(colab_lab,"structName_s")

# %%
#Nous le visualisons
plt.figure(1,figsize=(15,10)) 
pos=nx.fruchterman_reingold_layout(g)
nx.draw_networkx(g,pos=pos)

# %% [markdown]
# # Pour résumer
# Ici, je rappelle plus clairement les fonctions que vous pouvez utiliser.

# %% [markdown]
# ## Faire une requete et afficher les résultats en colonnes

# %%
domaine="UNIV-LYON/"
mots="abstract_t:(facile)"
dates="[2020 TO 2022]"
colonnes="title_s,authFullName_s,abstr*,structAcronym_s,structCountry_s,structAddress_s,structType_s,structName_s"

requete = "http://api.archives-ouvertes.fr/search/"+domaine+"?q="+mots+"&fq=publicationDate_s:"+dates+"&fl="+colonnes
exemple_facile = get_all_elements(requete)
exemple_facile
# Out:
# Nombre d'éléments au total :  14
# Éléments récupérés :  14
#                                                                                                 title_s  \
# 0                                     Co-clustering contraint pour le résumé de matrices document-terme
# 1   Synthesis of new Covalent Triazine Frameworks for Carbon Dioxide Photoreduction,Synthèse de nouv...
# 2   Unusually large "yaw" angle upon coordination of a new bulky unsymmetrical 3-hydroxyadamantyl-fu...
# 3   Intégration de la Gestion du Contexte et des Dispositifs IoT dans des Maisons Intelligentes basé...
# 4                                                        La production des vaches laitières Maraîchines
# 5   Le lycée permet-il aux jeunes de comprendre l’élevage ? État des lieux et propositions,Can high ...
# 6         Molecular engineering for the synthesis of inorganic nanomaterials for catalytic applications
# 7                                             Precursor-controlled synthesis of inorganic nanomaterials
# 8   Self-organization of silver nanoparticles with femtosecond laser in TiO2 matrix : Applications t...
# 9                    C(sp3)–H Bond Acylation with N-Acyl Imides under Photoredox/ Nickel Dual Catalysis
# 10  Méta-langage endomorphe et planification abstraite pour la reconnaissance des intentions en temp...
# 11  Développement de dispositifs de mesures biomécaniques pour l’aide à la conception des orthèses a...
# 12  Different warm-up modalities on swimming spring performance,Effets des modalites d'échauffement ...
# 13  Coinage Metal Complexes with Di-tertiary-butyl Sulfide as Precursors with Ultra-Low Decompositio...
#
#                                                                                          authFullName_s  \
# 0                                                    Margot Selosse,Julien Jacques,Christophe Biernacki
# 1                                                                                  Marcelo Alves Favaro
# 2                                                          Julien Petit,Paul-Alexis Pavard,Clément Camp
# 3                                                   Iago Felipe Trentin,Fano Ramparany,Olivier Boissier
# 4                                                                          Mollys Daunas,Anne Farruggia
# 5                                                 Alizée Chouteau,Catherine Disenhaus,Gilles Brunschwig
# 6                                                                                             S. Mishra
# 7                                                                                             S. Mishra
# 8                                                                                          Nipun Sharma
# 9   Taline Kerackian,Antonio Reina,Tetiana Krachko,Hugo Boddaert,Didier Bouyssi,Nuno Monteiro,Abderr...
# 10                                                                                        Antoine Gréa
# 11                                                                                     Khouloud Achouri
# 12                                                                                           Zied Abbes
# 13                                        Sweta Gahlot,Bhagyesh Purohit,Erwann Jeanneau,Shashank Mishra
#
#                                                                                         structAcronym_s  \
# 0                                  ERIC,UL2,UCBL,MODAL,Inria,LPP,CNRS,METRICS,CHRU Lille,Polytech Lille
# 1                                                                                    IRCELYON,CNRS,UCBL
# 2                                                                                    C2P2,UCBL,CPE,CNRS
# 3   Mines Saint-Étienne MSE,IMT,LHC,IOGS,UJM,CNRS,FAYOL-ENSMSE,Mines Saint-Étienne MSE,IMT,FAYOL-ENSMSE
# 4                                                                                        UMRH,VAS,INRAE
# 5                                                       IDELE,PEGASE,Institut Agro,INRAE,UMRH,VAS,INRAE
# 6                                                                           CDURABLE,IRCELYON,CNRS,UCBL
# 7                                                                           CDURABLE,IRCELYON,CNRS,UCBL
# 8                                                                                     LHC,UJM,CNRS,IOGS
# 9                                                                 CASYEN,ICBMS,CNRS,INSA Lyon,INSA,UCBL
# 10                                                               LIRIS,INSA Lyon,INSA,CNRS,UCBL,ECL,UL2
# 11                                                                   TIMC,VAS,CNRS,UGA,Grenoble INP,UGA
# 12                                   LIBM,UCBL,UJM,USMB [Université de Savoie] [Université de Chambéry]
# 13                                                       IRCELYON,CNRS,UCBL,CDURABLE,IRCELYON,CNRS,UCBL
#
#                                  structCountry_s  \
# 0   fr,fr,fr,fr,fr,fr,fr,fr,fr,fr,fr,fr,fr,fr,fr
# 1                                    fr,fr,fr,fr
# 2                                 fr,fr,fr,fr,fr
# 3               fr,fr,fr,fr,fr,fr,fr,fr,fr,fr,fr
# 4                                    fr,fr,fr,fr
# 5                     fr,fr,fr,fr,fr,fr,fr,fr,fr
# 6                                 fr,fr,fr,fr,fr
# 7                                 fr,fr,fr,fr,fr
# 8                                    fr,fr,fr,fr
# 9                     fr,fr,fr,fr,fr,fr,fr,fr,fr
# 10                 fr,fr,fr,fr,fr,fr,fr,fr,fr,fr
# 11                             fr,fr,fr,fr,fr,fr
# 12                                fr,fr,fr,fr,fr
# 13                 fr,fr,fr,fr,fr,fr,fr,fr,fr,fr
#
#                                                                                         structAddress_s  \
# 0   Université Lumière Lyon 2 5 avenue Pierre Mendès-France 69676 Bron Cedex,86\, rue Pasteur - 6900...
# 1   2 avenue Albert Einstein 69226 Villeurbanne cedex,43\, boulevard du 11 novembre 1918\, 69622 Vil...
# 2   43\, Bd. du 11 Novembre 1918\, Villeurbanne F-69616\,,43\, boulevard du 11 novembre 1918\, 69622...
# 3   158\, Cours Fauriel - 42023 Saint Étienne cedex 2,37-39 Rue Dareau\, 75014 Paris,18 rue du Profe...
# 4   INRAE / Site de Theix  / 63122 Saint-Genès-Champanelle,Université de Lyon\, VetAgro Sup\, 69280 ...
# 5   Paris,16\, le Clos 35590 Saint-Gilles,Institut Supérieur des Sciences Agronomiques\, Agroaliment...
# 6   2 avenue Albert Einstein 69226 Villeurbanne cedex,43\, boulevard du 11 novembre 1918\, 69622 Vil...
# 7   2 avenue Albert Einstein 69226 Villeurbanne cedex,43\, boulevard du 11 novembre 1918\, 69622 Vil...
# 8   18 rue du Professeur Lauras 42000 SAINT-ETIENNE,10 rue Tréfilerie - 42100 Saint-Étienne,2 avenue...
# 9   ICBMS UMR 5246 CNRS\, Université de Lyon\, Université Lyon 1\, CNRS\, INSA Lyon\, CPE Lyon\, bât...
# 10  Bâtiment Blaise Pascal - 20\, avenue Albert Einstein - 69621 Villeurbanne cedex,20 Avenue Albert...
# 11  Domaine de la Merci\, 38706 La Tronche\, France,Université de Lyon\, VetAgro Sup\, 69280 Marcy l...
# 12  CAMPUS SANTE INNOVATIONS - Bâtiment IRMIS - 10 rue de la Marandière 42270 Saint Priest en Jarez ...
# 13  2 avenue Albert Einstein 69226 Villeurbanne cedex,43\, boulevard du 11 novembre 1918\, 69622 Vil...
#
#                                                                                            structType_s  \
# 0   laboratory,institution,institution,regroupinstitution,researchteam,laboratory,institution,labora...
# 1                                                 laboratory,institution,institution,regroupinstitution
# 2                                     laboratory,institution,regroupinstitution,institution,institution
# 3   regrouplaboratory,regroupinstitution,laboratory,institution,institution,institution,laboratory,r...
# 4                                                        laboratory,institution,institution,institution
# 5   institution,laboratory,institution,regroupinstitution,institution,laboratory,institution,institu...
# 6                                    researchteam,laboratory,institution,institution,regroupinstitution
# 7                                    researchteam,laboratory,institution,institution,regroupinstitution
# 8                                                        laboratory,institution,institution,institution
# 9   researchteam,laboratory,institution,institution,institution,regroupinstitution,regroupinstitutio...
# 10  laboratory,institution,regroupinstitution,regroupinstitution,institution,institution,regroupinst...
# 11                 laboratory,institution,institution,regroupinstitution,institution,regroupinstitution
# 12                                    laboratory,institution,regroupinstitution,institution,institution
# 13  laboratory,institution,institution,regroupinstitution,researchteam,laboratory,institution,instit...
#
#                                                                                            structName_s  \
# 0   Entrepôts\, Représentation et Ingénierie des Connaissances,Université Lumière - Lyon 2,Universit...
# 1   Institut de recherches sur la catalyse et l'environnement de Lyon,Centre National de la Recherch...
# 2   Laboratoire de Chimie\, Catalyse\, Polymères et Procédés\, R 5265,Université Claude Bernard Lyon...
# 3   École des Mines de Saint-Étienne,Institut Mines-Télécom [Paris],Laboratoire Hubert Curien [Saint...
# 4   Unité Mixte de Recherche sur les Herbivores - UMR 1213,VetAgro Sup - Institut national d'enseign...
# 5   Institut de l'élevage,Physiologie\, Environnement et Génétique pour l'Animal et les Systèmes d'E...
# 6   IRCELYON-C'Durable,Institut de recherches sur la catalyse et l'environnement de Lyon,Centre Nati...
# 7   IRCELYON-C'Durable,Institut de recherches sur la catalyse et l'environnement de Lyon,Centre Nati...
# 8   Laboratoire Hubert Curien [Saint Etienne],Université Jean Monnet [Saint-Étienne],Centre National...
# 9   Catalyse Synthèse et Environnement,Institut de Chimie et Biochimie Moléculaires et Supramolécula...
# 10  Laboratoire d'InfoRmatique en Image et Systèmes d'information,Institut National des Sciences App...
# 11  Translational Innovation in Medicine and Complexity | Recherche Translationnelle et Innovation e...
# 12  Laboratoire Interuniversitaire de Biologie de la Motricité,Université Claude Bernard Lyon 1,Univ...
# 13  Institut de recherches sur la catalyse et l'environnement de Lyon,Centre National de la Recherch...
#
#                                                                                              abstract_s
# 0   Le co-clustering est une méthode de fouille de données qui produit simul-tanément un clustering ...
# 1   Using sunlight as a renewable source of energy to promote carbon dioxide (CO2) conversion is an ...
# 2   The facile synthesis of a new 3-hydroxyadamantyl-functionalized N-heterocyclic carbene (NHC) lig...
# 3   Avec les technologies IoT\, la domotique s'oriente vers la maison intelligente. Les utilisateurs...
# 4   La race bovine Maraîchine est une race mixte lait-viande à petit effectif. Cette race intéresse ...
# 5   Aujourd’hui les liens entre agriculture et société s’étiolent\, avec un niveau de connaissances ...
# 6   Industrial development of chemical solution and vapor routes to inorganic nanomaterials (e.g.\, ...
# 7   Industrial development of chemical solution and vapor routes to inorganic nanomaterials (e.g.\, ...
# 8   Self-organization of metallic nanoparticles in a medium is an efficient and a low-cost way to pr...
# 9   A novel Ni/photoredox-catalyzed acylation of aliphatic substrates\, including simple alkanes and...
# 10  L’interaction personne-machine fait partie des problèmes les plus complexes dans le domaine de l...
# 11  L’orthèse est un dispositif médical qui permet de compenser\, soutenir ou protéger une partie du...
# 12  Swimming is a very demanding sport which requires extreme muscle strength and endurance. Only fr...
# 13  We report here the synthesis of [Cu2(TFA)4(tBu2S)2] (1)\, [Ag4(TFA)4(tBu2S)4] (2) and [AuCl(tBu2...

# %% [markdown]
# ## Exporter en .csv

# %%
exemple_facile.to_csv("mon_fichier.csv")

# %% [markdown]
# ## Générer un graphe de co-autheurs, le visualiser et l'exporter

# %%
g_facile = co_occurence_network(exemple_facile,"authFullName_s",threshold=0)

# %%
plt.figure(1,figsize=(5,3)) 
pos=nx.fruchterman_reingold_layout(g_facile)
nx.draw_networkx(g_facile,pos=pos)

# %%
nx.write_graphml(g_facile,"mon_graph.graphml")

# %% [markdown]
# ## Générer un graphe de laboratoire

# %%
g_facile = co_occurence_network_laboratory(exemple_facile,"structName_s",threshold=0)

# %%
plt.figure(1,figsize=(5,3)) 
pos=nx.fruchterman_reingold_layout(g_facile)
nx.draw_networkx(g_facile,pos=pos)
